# %%
import os
import pandas as pd

PATH_DATA      = "/content/drive/MyDrive/Text Mining Project IV Prediction/Data (Raw and processed data from python scripts)/"
RAW_DATA       = PATH_DATA + "Raw Data/"
PROCESSED_DATA = PATH_DATA + "Processed Data/"
COMPLETED_DATA = PATH_DATA + "Completed Data/"

os.listdir(COMPLETED_DATA)
# Out:
# ['MSFT.csv', 'MSFT_delta1week_v1.csv', 'MSFT_delta1_formated.csv']

# %%
temp = pd.read_csv(f"{COMPLETED_DATA}MSFT_delta1_formated.csv")

temp_2 = pd.read_csv(f"{COMPLETED_DATA}MSFT_delta1week_v1.csv")

# %%
temp_2
# Out:
#      Unnamed: 0        Date  \
# 0             0  2015-01-09
# 1             1  2015-01-16
# 2             2  2015-01-23
# 3             3  2015-01-30
# 4             4  2015-02-06
# ..          ...         ...
# 255         255  2019-11-29
# 256         256  2019-12-06
# 257         257  2019-12-13
# 258         258  2019-12-20
# 259         259  2019-12-27
#
#                                                 Tweets  Changed  \
# 0    {'Quantitative Trading: An Average Return of 3...    False
# 1    {'The one U.S. Company rumored to be intereste...    False
# 2    {'Twitter May Have Near-Term Headwinds but Jim...     True
# 3    {'PSA: @TheEdWood has informed me that the Out...     True
# 4    {'Is #Microsoft Cheap Again? $MSFT  http://goo...     True
# ..                                                 ...      ...
# 255  {'$DEWM gap up to 0017s, low volume though. Le...    False
# 256  {'$GATA OVERSOLD!! float 9 million? Valuation ...    False
# 257  {'Top stocks on trend MELTDOWN watchlist: $MSF...    False
# 258  {'Some of todays top open interest changes 12....    False
# 259  {'$MSFT $FB Green !  Dips got bot !', 'This We...     True
#
#                                         Tweets no link
# 0    ['$INTC $BBRY $MSFT red everywhere! I wonder i...
# 1    ['The one U.S. Company rumored to be intereste...
# 2    ['@satyanadella just gave shoutout to Acompli ...
# 3    ['PSA: @TheEdWood has informed me that the Out...
# 4    ['$SAP revamps Business Suite, optimizes for H...
# ..                                                 ...
# 255  ['$DEWM gap up to 0017s, low volume though. Le...
# 256  ['$GATA OVERSOLD!! float 9 million? Valuation ...
# 257  ['Top stocks on trend MELTDOWN watchlist: $MSF...
# 258  ['Some of todays top open interest changes 12....
# 259  ['$MSFT $FB Green !  Dips got bot !', 'This We...
#
# [260 rows x 5 columns]
